# %% [markdown]
# # Statistical Learning Project working title
# Tool/topic list
# - hi

# %%
# imports
import numpy as np
import pandas as pd
import sklearn

# %matplotlib inline
from IPython.display import display, Markdown, Latex
import pandas_profiling
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

# %%
# read in data
ath = pd.read_csv("data/athlete_events.csv", index_col=False, header=0, names=['ath_id', 'name', 'sex', 'age', 'height', 'weight', 'team', 'noc', 'games',
       'year', 'season', 'city', 'sport', 'event', 'medal'])
regions = pd.read_csv("data/noc_regions.csv") # translates National Olympic Committees (NOC)

# %%
ath.index.name = 'id'

# %% [markdown]
# ## Explore and Clean

# %%
ath.head()
# Out:
#     ath_id                      name sex   age  height  weight  \
# id
# 0        1                 A Dijiang   M  24.0   180.0    80.0
# 1        2                  A Lamusi   M  23.0   170.0    60.0
# 2        3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3        4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4        5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
#
#               team  noc        games  year  season       city          sport  \
# id
# 0            China  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1            China  CHN  2012 Summer  2012  Summer     London           Judo
# 2          Denmark  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3   Denmark/Sweden  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4      Netherlands  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                                event medal
# id
# 0        Basketball Men's Basketball   NaN
# ...

# %%
profile = pandas_profiling.ProfileReport(ath)
rejected_variables = profile.get_rejected_variables(threshold=0.9) # empty

profile
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %%
# replace nan in medal column with "No"
ath['medal'].fillna("No", inplace=True)

# %%
# age, height, and weight have missing values
# does this correlate with year?

nan = ath[ath.isnull().any(axis=1)]
age_nan = ath[ath['age'].isnull()]
height_nan = ath[ath['height'].isnull()]
weight_nan = ath[ath['weight'].isnull()]

# %%
df_agg = nan.groupby('noc').count()
g = df_agg['ath_id'].groupby(level=0, group_keys=False)
res = g.apply(lambda x: x.order(ascending=False).head(3))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/claudio/anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     917             try:
# --> 918                 result = self._python_apply_general(f)
#     919             except Exception:
#
# /Users/claudio/anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f)
#     935         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 936                                                    self.axis)
#     937
#
# /Users/claudio/anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in apply(self, f, data, axis)
#    2272             group_axes = _get_axes(group)
# -> 2273             res = f(group)
#    2274             if not _is_indexed_like(res, group_axes):
#
# ...

# %%
# what is the distribution of year before removing non-null values?
# the more recent the year, the more rows.

plt.hist(ath['year'])
plt.xlabel('Year')
plt.ylabel('Number of rows')
plt.title('Distribution of Year')
plt.grid(True)
plt.show()

# %%
# what is the distribution of null values by Year?
# Least nan for recent years, dispite there being more entries for recent years

plt.hist(nan['year'])
plt.xlabel('Year')
plt.ylabel('Number of rows with at least one nan')
plt.title('Nan by Year')
plt.grid(True)
plt.show()

# %%
# what is the distribution of age null values by Year?
# Least nan for recent years, dispite there being more entries for recent years

plt.hist(age_nan['year'])
plt.xlabel('Year')
plt.ylabel('Number of rows with at least one age nan')
plt.title('Age nan by Year')
plt.grid(True)
plt.show()

# %%
# what is the distribution of height null values by Year?
# Least nan for recent years, dispite there being more entries for recent years

plt.hist(height_nan['year'])
plt.xlabel('Year')
plt.ylabel('Number of rows with at least one height nan')
plt.title('Height nan by Year')
plt.grid(True)
plt.show()

# %%
# what is the distribution of age null values by Year?
# Least nan for recent years, dispite there being more entries for recent years

plt.hist(weight_nan['year'])
plt.xlabel('Year')
plt.ylabel('Number of rows with at least one weight nan')
plt.title('Weight nan by Year')
plt.grid(True)
plt.show()
